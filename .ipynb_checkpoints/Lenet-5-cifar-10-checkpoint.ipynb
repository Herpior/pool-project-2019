# %%
skip_training = False
save_all = True

# %%
import os
if os.path.isdir('../data'):
    data_dir = '../data'
else:
    raise NotImplementedError()
print('The data directory is %s' % data_dir)
# Out:
# The data directory is ../data

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torchvision
import torchvision.transforms as transforms

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Function

# %%
device = torch.device('cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root=data_dir+"/cifar-10/train", 
                                        train=True,
                                        download=True, 
                                        transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)

testset = torchvision.datasets.CIFAR10(root=data_dir+"/cifar-10/test", 
                                       train=False,
                                       download=True, 
                                       transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False)

classes = ('airplane', 'automobile', 'bird', 'cat', 'deer', 
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def convert_to_imshow_format(image):
    # first convert back to [0,1] range from [-1,1] range
    image = image / 2 + 0.5
    image = image.numpy()
    # convert from CHW to HWC
    # from 3x32x32 to 32x32x3
    return image.transpose(1,2,0)

def plot_images(images, n_rows=1):
    fig, axes = plt.subplots(n_rows, len(images) // n_rows, figsize=(2*len(images)//n_rows,2.25*n_rows))
    for idx, image in enumerate(images):
        ax_ind = (idx%n_rows,idx//n_rows)
        if n_rows is 1:
            ax_ind = idx
        axes[ax_ind].imshow(convert_to_imshow_format(image))
        axes[ax_ind].set_title(classes[labels[idx]])
        axes[ax_ind].set_xticks([])
        axes[ax_ind].set_yticks([])

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
plot_images(images[:8], n_rows=2)

# %%
class MixerFunction(Function):
    @staticmethod
    def forward(ctx, x, alpha, kernel_size, stride):
        avg_forward = F.avg_pool2d(x, kernel_size, stride)
        max_forward, max_ind = F.max_pool2d(x, kernel_size, stride, return_indices=True)
        kernel_size = torch.tensor([kernel_size])
        stride = torch.tensor([stride])
        ctx.save_for_backward(x, alpha, max_forward, avg_forward, max_ind, kernel_size, stride)
        return alpha * max_forward + (1-alpha) * avg_forward
    
    
    @staticmethod
    def backward(ctx, dy):
        x, alpha, max_forward, avg_forward,max_ind, kernel_size, stride = ctx.saved_tensors
        kernel_size = kernel_size.item()
        stride = stride.item()
        grad_input = grad_alpha = None
        
        if ctx.needs_input_grad[0]:
            grad_avg = F.interpolate(dy, scale_factor=stride, mode='nearest')
            grad_avg = grad_avg*1.0/(stride*stride)
            #grad_max = F.max_unpool2d(dy, max_ind, kernel_size,stride)#,output_size = x.shape)
            #print(grad_max.shape)
            grad_max = torch.zeros(x.shape).view(1,-1).squeeze(0)
            grad_max[max_ind] = dy#.view(1, -1)
            grad_max = grad_max.view(x.shape)
            grad_input = (alpha * grad_max + (1-alpha)*grad_avg)
            #print(grad_input)
        if ctx.needs_input_grad[1]:
            #print(dy.shape)
            #print(max_forward.shape)
            grad_alpha = (dy * (avg_forward - max_forward)).sum(-1).sum(-1)
            #print(grad_alpha.shape)
            #print(grad_alpha)
            #print(max_forward - avg_forward)
            
        return grad_input, grad_alpha, None, None
    
    
class MixedMaxAvgPool2d(nn.Module):
    def __init__(self, kernel_size, stride=None, padding=0):
        super(MixedMaxAvgPool2d, self).__init__()
        self.stride = stride
        self.kernel = kernel_size
        self.avg = nn.AvgPool2d(kernel_size, stride=stride, padding=padding)
        self.max = nn.MaxPool2d(kernel_size, stride=stride, padding=padding)#, return_indices=True)
        #self.a = nn.Linear(1,1,bias=False)
        self.alpha = nn.Parameter(torch.rand(1, requires_grad=True)) #nn.Linear(1, 1, bias=False)
    
    #def parameters(self):
    #    return [self.alpha]
    
    def forward(self, x):
        #alpha = torch.clamp(self.a(torch.ones(1)), min=0, max=1).unsqueeze(0)
        alpha = torch.clamp(self.alpha, min=0, max=1)
        return (alpha * self.max.forward(x) + (1-alpha) * self.avg.forward(x))
        #return MixerFunction.apply(x, self.alpha, self.kernel, self.stride)#, self.avg, self.max)

# %%
class FiftyFiftyMaxAvgPool2d(nn.Module):
    def __init__(self, kernel_size, stride=None, padding=0):
        super(FiftyFiftyMaxAvgPool2d, self).__init__()
        self.avg = nn.AvgPool2d(kernel_size, stride=stride, padding=padding)
        self.max = nn.MaxPool2d(kernel_size, stride=stride, padding=padding)#, return_indices=True)
        self.alpha = torch.tensor([0.5]) #nn.Linear(1, 1, bias=False)
    
    def forward(self, x):
        alpha = torch.clamp(self.alpha, min=0, max=1)
        return (alpha * self.max.forward(x) + (1-alpha) * self.avg.forward(x))

# %%
class MinPool2d(nn.Module):
    def __init__(self, kernel_size, stride=None, padding=0):
        super(MinPool2d, self).__init__()
        self.max = nn.MaxPool2d(kernel_size, stride=stride, padding=padding)#, return_indices=True)
    
    def forward(self, x):
        return -self.max(-x)

# %%
# Let us test the shapes
x = torch.tensor([[1.0,-1.0,1.0,-1.0],[0,0,0,0],[1.0,-1.0,1.0,-1.0],[0,0,0,0]]).unsqueeze(0)
#print(x.shape)
act_fn = MixedMaxAvgPool2d(2,2)
lin = nn.Linear(4,1,bias=False)
lin.weight.data.fill_(0.25)
criterion = nn.MSELoss()
optimizer = optim.SGD(act_fn.parameters(), lr=0.001, momentum=0.9)

# zero the parameter gradients
optimizer.zero_grad()

# forward + backward + optimize
y = act_fn.forward(x)
#print(y)
#print(y.shape)
#print(torch.ones([1,1]).shape)
y = lin.forward(y.view(4)).unsqueeze(0)

#print(y)
#print(y.shape)
z = torch.tensor([0.0])

loss = criterion(y, z)
#loss.backward()
#optimizer.step()
#print(act_fn.alpha)

#dy = torch.ones(1,1,1).unsqueeze(0)
#dx = act_fn.backward(dy)
#assert dx.shape == x.shape, "Bad shape of dx: dx.shape={}, x.shape={}".format(dx.shape, x.shape)
#print("The shapes seem to be ok.")

# %%
class Net(nn.Module):
    def __init__(self, PoolingLayer1, PoolingLayer2):
        super(Net, self).__init__()
        self.net2d = nn.Sequential(
            nn.Conv2d(3, 16, 5),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            PoolingLayer1,
            nn.Conv2d(16, 32, 5),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            PoolingLayer2,)
        flat_features = 32*5*5
        self.net1d = nn.Sequential(
            nn.Linear(flat_features, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, 10),)
        # YOUR CODE HERE
        #raise NotImplementedError()

    def forward(self, x):
        # YOUR CODE HERE
        x = self.net2d(x)
        x = x.view(-1, self.num_flat_features(x))
        x = self.net1d(x)
        return x
        #raise NotImplementedError()
        
    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %%
def check_shapes(net, trainloader):
    # Feed a batch of images from the training data to test the network
    with torch.no_grad():
        dataiter = iter(trainloader)
        images, labels = dataiter.next()
        images = images.to(device)
        print('Shape of the input tensor:', images.shape)

        y = net(images)
        assert y.shape == torch.Size([32, 10]), "Bad shape of y: y.shape={}".format(y.shape)

    print('The shapes seem to be ok.')

# %%
# This function computes the accuracy on the test dataset
def compute_accuracy(net, testloader):
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %%
def train_model(net, n_epochs):
    # Define the loss and the optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    # Let us train the network for 10 epochs (one epoch is one pass though the training data)
    # The loss should go down during training
    net.train()
    for epoch in range(n_epochs):
        running_loss = 0.0
        print_every = 200  # mini-batches
        for i, (inputs, labels) in enumerate(trainloader, 0):
            # Transfer to GPU
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if (i % print_every) == (print_every-1):
                print('[%d, %5d] loss: %.3f' % (epoch+1, i+1, running_loss/print_every))
                running_loss = 0.0
            if skip_training:
                break

        # Print accuracy after every epoch
        accuracy = compute_accuracy(net, testloader)
        print('Accuracy of the network on the test images: %.3f' % accuracy)
        #print(net.net2d[3].a.weight)
        #print(net.net2d[7].a.weight)

        if skip_training:
            break

    print('Finished Training')

# %%
def save_model(net, name):
    # Save the network to a file, submit this file together with your notebook
    filename = name
    if not skip_training:
        try:
            do_save = 'yes'
            if not save_all:
                do_save = input('Do you want to save the model (type yes to confirm)? ').lower()
            if do_save == 'yes':
                torch.save(net.state_dict(), filename)
                print('Model saved to %s' % filename)
            else:
                print('Model not saved')
        except:
            raise Exception('The notebook should be run or validated with skip_training=True.')
    else:
        net.load_state_dict(torch.load(filename, map_location=lambda storage, loc: storage))
        net.to(device)
        print('Model loaded from %s' % filename)

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(nn.LPPool2d(2,2, 2), nn.LPPool2d(2,2, 2))
net.to(device)
check_shapes(net, trainloader)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.

# %%
n_epochs = 20

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_lp_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.236
# [1,   400] loss: 2.074
# [1,   600] loss: 1.882
# [1,   800] loss: 1.736
# [1,  1000] loss: 1.626
# [1,  1200] loss: 1.561
# [1,  1400] loss: 1.502
# Accuracy of the network on the test images: 0.461
# [2,   200] loss: 1.428
# [2,   400] loss: 1.408
# [2,   600] loss: 1.355
# [2,   800] loss: 1.320
# [2,  1000] loss: 1.308
# [2,  1200] loss: 1.309
# [2,  1400] loss: 1.243
# Accuracy of the network on the test images: 0.570
# [3,   200] loss: 1.200
# [3,   400] loss: 1.167
# [3,   600] loss: 1.190
# [3,   800] loss: 1.163
# [3,  1000] loss: 1.140
# [3,  1200] loss: 1.134
# [3,  1400] loss: 1.097
# Accuracy of the network on the test images: 0.617
# [4,   200] loss: 1.081
# [4,   400] loss: 1.067
# [4,   600] loss: 1.062
# [4,   800] loss: 1.027
# [4,  1000] loss: 1.057
# [4,  1200] loss: 1.009
# [4,  1400] loss: 0.998
# Accuracy of the network on the test images: 0.636
# [5,   200] loss: 0.950
# [5,   400] loss: 0.960
# [5,   600] loss: 0.967
# [5,   800] loss: 0.960
# [5,  1000] loss: 0.952
# [5,  1200] loss: 0.973
# [5,  1400] loss: 0.944
# Accuracy of the network on the test images: 0.649
# [6,   200] loss: 0.847
# [6,   400] loss: 0.902
# [6,   600] loss: 0.874
# [6,   800] loss: 0.880
# [6,  1000] loss: 0.902
# [6,  1200] loss: 0.902
# [6,  1400] loss: 0.880
# Accuracy of the network on the test images: 0.644
# [7,   200] loss: 0.822
# [7,   400] loss: 0.815
# [7,   600] loss: 0.813
# [7,   800] loss: 0.829
# [7,  1000] loss: 0.836
# [7,  1200] loss: 0.858
# [7,  1400] loss: 0.798
# Accuracy of the network on the test images: 0.674
# [8,   200] loss: 0.753
# [8,   400] loss: 0.785
# [8,   600] loss: 0.783
# [8,   800] loss: 0.764
# [8,  1000] loss: 0.767
# [8,  1200] loss: 0.767
# [8,  1400] loss: 0.794
# Accuracy of the network on the test images: 0.677
# [9,   200] loss: 0.702
# [9,   400] loss: 0.716
# [9,   600] loss: 0.733
# [9,   800] loss: 0.714
# [9,  1000] loss: 0.729
# [9,  1200] loss: 0.716
# [9,  1400] loss: 0.733
# Accuracy of the network on the test images: 0.694
# [10,   200] loss: 0.657
# [10,   400] loss: 0.673
# [10,   600] loss: 0.679
# [10,   800] loss: 0.671
# [10,  1000] loss: 0.705
# [10,  1200] loss: 0.691
# [10,  1400] loss: 0.693
# Accuracy of the network on the test images: 0.700
# [11,   200] loss: 0.608
# [11,   400] loss: 0.610
# [11,   600] loss: 0.629
# [11,   800] loss: 0.639
# [11,  1000] loss: 0.650
# [11,  1200] loss: 0.660
# [11,  1400] loss: 0.669
# Accuracy of the network on the test images: 0.679
# [12,   200] loss: 0.539
# [12,   400] loss: 0.575
# [12,   600] loss: 0.574
# [12,   800] loss: 0.596
# [12,  1000] loss: 0.625
# [12,  1200] loss: 0.603
# [12,  1400] loss: 0.627
# Accuracy of the network on the test images: 0.700
# [13,   200] loss: 0.511
# [13,   400] loss: 0.552
# [13,   600] loss: 0.553
# [13,   800] loss: 0.577
# [13,  1000] loss: 0.554
# [13,  1200] loss: 0.578
# [13,  1400] loss: 0.588
# Accuracy of the network on the test images: 0.703
# [14,   200] loss: 0.495
# [14,   400] loss: 0.492
# [14,   600] loss: 0.502
# [14,   800] loss: 0.518
# [14,  1000] loss: 0.508
# [14,  1200] loss: 0.555
# [14,  1400] loss: 0.572
# Accuracy of the network on the test images: 0.692
# [15,   200] loss: 0.448
# [15,   400] loss: 0.436
# [15,   600] loss: 0.481
# [15,   800] loss: 0.482
# [15,  1000] loss: 0.491
# [15,  1200] loss: 0.519
# [15,  1400] loss: 0.521
# Accuracy of the network on the test images: 0.695
# [16,   200] loss: 0.408
# [16,   400] loss: 0.426
# [16,   600] loss: 0.425
# [16,   800] loss: 0.459
# [16,  1000] loss: 0.460
# [16,  1200] loss: 0.475
# [16,  1400] loss: 0.466
# Accuracy of the network on the test images: 0.689
# [17,   200] loss: 0.367
# [17,   400] loss: 0.393
# [17,   600] loss: 0.398
# [17,   800] loss: 0.417
# [17,  1000] loss: 0.429
# [17,  1200] loss: 0.447
# [17,  1400] loss: 0.449
# Accuracy of the network on the test images: 0.685
# [18,   200] loss: 0.330
# [18,   400] loss: 0.370
# [18,   600] loss: 0.397
# [18,   800] loss: 0.377
# [18,  1000] loss: 0.421
# [18,  1200] loss: 0.431
# [18,  1400] loss: 0.401
# Accuracy of the network on the test images: 0.690
# [19,   200] loss: 0.322
# [19,   400] loss: 0.345
# [19,   600] loss: 0.343
# [19,   800] loss: 0.373
# [19,  1000] loss: 0.378
# [19,  1200] loss: 0.406
# [19,  1400] loss: 0.389
# Accuracy of the network on the test images: 0.694
# [20,   200] loss: 0.291
# [20,   400] loss: 0.318
# [20,   600] loss: 0.337
# [20,   800] loss: 0.328
# [20,  1000] loss: 0.332
# [20,  1200] loss: 0.381
# [20,  1400] loss: 0.376
# Accuracy of the network on the test images: 0.686
# Finished Training
# Model saved to lenet-5_lp_pool.pth
# Accuracy of the network on the test images: 0.686

# %%
# Let us look at the confusion matrix computed for the test set
import sklearn.metrics as skmetrics

def confusion_matrix(net, testloader):
    net.eval()
    true_labels = []
    predictions = []
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            predicted = torch.argmax(outputs.data, 1)
            true_labels.append(labels.cpu().numpy())
            predictions.append(predicted.cpu().numpy())
    true_labels = np.hstack(true_labels)
    predictions = np.hstack(predictions)

    return skmetrics.confusion_matrix(true_labels, predictions)

# %%
import seaborn as sns

c_matrix = confusion_matrix(net, testloader)
plt.figure(figsize=(6, 6))
plt.title("Confusion matrix")
sns.heatmap(c_matrix, cmap='Blues', annot=True, xticklabels=classes, yticklabels=classes, fmt='g', cbar=False)
plt.xlabel('predictions')
plt.ylabel('true labels')
# Out:
# Text(33,0.5,'true labels')

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(nn.MaxPool2d(2, 2), nn.MaxPool2d(2, 2))
net.to(device)
check_shapes(net, trainloader)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_max_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.267
# [1,   400] loss: 2.072
# [1,   600] loss: 1.850
# [1,   800] loss: 1.751
# [1,  1000] loss: 1.655
# [1,  1200] loss: 1.560
# [1,  1400] loss: 1.507
# Accuracy of the network on the test images: 0.462
# [2,   200] loss: 1.418
# [2,   400] loss: 1.393
# [2,   600] loss: 1.353
# [2,   800] loss: 1.308
# [2,  1000] loss: 1.274
# [2,  1200] loss: 1.265
# [2,  1400] loss: 1.242
# Accuracy of the network on the test images: 0.560
# [3,   200] loss: 1.194
# [3,   400] loss: 1.216
# [3,   600] loss: 1.163
# [3,   800] loss: 1.157
# [3,  1000] loss: 1.116
# [3,  1200] loss: 1.125
# [3,  1400] loss: 1.137
# Accuracy of the network on the test images: 0.602
# [4,   200] loss: 1.084
# [4,   400] loss: 1.093
# [4,   600] loss: 1.045
# [4,   800] loss: 1.061
# [4,  1000] loss: 1.061
# [4,  1200] loss: 1.067
# [4,  1400] loss: 1.038
# Accuracy of the network on the test images: 0.620
# [5,   200] loss: 0.977
# [5,   400] loss: 0.986
# [5,   600] loss: 1.006
# [5,   800] loss: 0.986
# [5,  1000] loss: 0.985
# [5,  1200] loss: 0.991
# [5,  1400] loss: 0.978
# Accuracy of the network on the test images: 0.631
# [6,   200] loss: 0.958
# [6,   400] loss: 0.942
# [6,   600] loss: 0.892
# [6,   800] loss: 0.922
# [6,  1000] loss: 0.931
# [6,  1200] loss: 0.923
# [6,  1400] loss: 0.930
# Accuracy of the network on the test images: 0.651
# [7,   200] loss: 0.858
# [7,   400] loss: 0.863
# [7,   600] loss: 0.863
# [7,   800] loss: 0.880
# [7,  1000] loss: 0.880
# [7,  1200] loss: 0.871
# [7,  1400] loss: 0.872
# Accuracy of the network on the test images: 0.675
# [8,   200] loss: 0.804
# [8,   400] loss: 0.813
# [8,   600] loss: 0.809
# [8,   800] loss: 0.830
# [8,  1000] loss: 0.823
# [8,  1200] loss: 0.821
# [8,  1400] loss: 0.818
# Accuracy of the network on the test images: 0.667
# [9,   200] loss: 0.744
# [9,   400] loss: 0.755
# [9,   600] loss: 0.762
# [9,   800] loss: 0.793
# [9,  1000] loss: 0.791
# [9,  1200] loss: 0.767
# [9,  1400] loss: 0.773
# Accuracy of the network on the test images: 0.678
# [10,   200] loss: 0.700
# [10,   400] loss: 0.710
# [10,   600] loss: 0.717
# [10,   800] loss: 0.721
# [10,  1000] loss: 0.748
# [10,  1200] loss: 0.764
# [10,  1400] loss: 0.741
# Accuracy of the network on the test images: 0.685
# [11,   200] loss: 0.665
# [11,   400] loss: 0.672
# [11,   600] loss: 0.671
# [11,   800] loss: 0.681
# [11,  1000] loss: 0.678
# [11,  1200] loss: 0.690
# [11,  1400] loss: 0.714
# Accuracy of the network on the test images: 0.682
# [12,   200] loss: 0.608
# [12,   400] loss: 0.635
# [12,   600] loss: 0.643
# [12,   800] loss: 0.651
# [12,  1000] loss: 0.662
# [12,  1200] loss: 0.643
# [12,  1400] loss: 0.691
# Accuracy of the network on the test images: 0.686
# [13,   200] loss: 0.572
# [13,   400] loss: 0.574
# [13,   600] loss: 0.587
# [13,   800] loss: 0.600
# [13,  1000] loss: 0.615
# [13,  1200] loss: 0.623
# [13,  1400] loss: 0.608
# Accuracy of the network on the test images: 0.692
# [14,   200] loss: 0.541
# [14,   400] loss: 0.562
# [14,   600] loss: 0.565
# [14,   800] loss: 0.556
# [14,  1000] loss: 0.551
# [14,  1200] loss: 0.576
# [14,  1400] loss: 0.578
# Accuracy of the network on the test images: 0.692
# [15,   200] loss: 0.476
# [15,   400] loss: 0.519
# [15,   600] loss: 0.511
# [15,   800] loss: 0.531
# [15,  1000] loss: 0.552
# [15,  1200] loss: 0.542
# [15,  1400] loss: 0.535
# Accuracy of the network on the test images: 0.685
# [16,   200] loss: 0.458
# [16,   400] loss: 0.455
# [16,   600] loss: 0.484
# [16,   800] loss: 0.492
# [16,  1000] loss: 0.502
# [16,  1200] loss: 0.519
# [16,  1400] loss: 0.534
# Accuracy of the network on the test images: 0.688
# [17,   200] loss: 0.426
# [17,   400] loss: 0.447
# [17,   600] loss: 0.457
# [17,   800] loss: 0.507
# [17,  1000] loss: 0.454
# [17,  1200] loss: 0.484
# [17,  1400] loss: 0.484
# Accuracy of the network on the test images: 0.688
# [18,   200] loss: 0.375
# [18,   400] loss: 0.402
# [18,   600] loss: 0.421
# [18,   800] loss: 0.426
# [18,  1000] loss: 0.460
# [18,  1200] loss: 0.427
# [18,  1400] loss: 0.479
# Accuracy of the network on the test images: 0.674
# [19,   200] loss: 0.350
# [19,   400] loss: 0.373
# [19,   600] loss: 0.405
# [19,   800] loss: 0.400
# [19,  1000] loss: 0.403
# [19,  1200] loss: 0.438
# [19,  1400] loss: 0.415
# Accuracy of the network on the test images: 0.670
# [20,   200] loss: 0.320
# [20,   400] loss: 0.344
# [20,   600] loss: 0.357
# [20,   800] loss: 0.379
# [20,  1000] loss: 0.377
# [20,  1200] loss: 0.400
# [20,  1400] loss: 0.431
# Accuracy of the network on the test images: 0.674
# Finished Training
# Model saved to lenet-5_max_pool.pth
# Accuracy of the network on the test images: 0.674

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(nn.AvgPool2d(2, 2), nn.AvgPool2d(2, 2))
net.to(device)
check_shapes(net, trainloader)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_avg_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.289
# [1,   400] loss: 2.222
# [1,   600] loss: 2.101
# [1,   800] loss: 1.972
# [1,  1000] loss: 1.863
# [1,  1200] loss: 1.787
# [1,  1400] loss: 1.702
# Accuracy of the network on the test images: 0.409
# [2,   200] loss: 1.609
# [2,   400] loss: 1.541
# [2,   600] loss: 1.513
# [2,   800] loss: 1.482
# [2,  1000] loss: 1.444
# [2,  1200] loss: 1.420
# [2,  1400] loss: 1.414
# Accuracy of the network on the test images: 0.492
# [3,   200] loss: 1.336
# [3,   400] loss: 1.328
# [3,   600] loss: 1.308
# [3,   800] loss: 1.320
# [3,  1000] loss: 1.304
# [3,  1200] loss: 1.271
# [3,  1400] loss: 1.255
# Accuracy of the network on the test images: 0.559
# [4,   200] loss: 1.224
# [4,   400] loss: 1.217
# [4,   600] loss: 1.186
# [4,   800] loss: 1.193
# [4,  1000] loss: 1.162
# [4,  1200] loss: 1.184
# [4,  1400] loss: 1.175
# Accuracy of the network on the test images: 0.591
# [5,   200] loss: 1.109
# [5,   400] loss: 1.113
# [5,   600] loss: 1.111
# [5,   800] loss: 1.110
# [5,  1000] loss: 1.087
# [5,  1200] loss: 1.104
# [5,  1400] loss: 1.091
# Accuracy of the network on the test images: 0.616
# [6,   200] loss: 1.056
# [6,   400] loss: 1.028
# [6,   600] loss: 1.045
# [6,   800] loss: 1.034
# [6,  1000] loss: 1.001
# [6,  1200] loss: 1.021
# [6,  1400] loss: 1.014
# Accuracy of the network on the test images: 0.630
# [7,   200] loss: 0.965
# [7,   400] loss: 0.976
# [7,   600] loss: 0.959
# [7,   800] loss: 0.968
# [7,  1000] loss: 0.941
# [7,  1200] loss: 0.958
# [7,  1400] loss: 0.962
# Accuracy of the network on the test images: 0.649
# [8,   200] loss: 0.880
# [8,   400] loss: 0.909
# [8,   600] loss: 0.899
# [8,   800] loss: 0.924
# [8,  1000] loss: 0.895
# [8,  1200] loss: 0.896
# [8,  1400] loss: 0.892
# Accuracy of the network on the test images: 0.671
# [9,   200] loss: 0.845
# [9,   400] loss: 0.836
# [9,   600] loss: 0.855
# [9,   800] loss: 0.849
# [9,  1000] loss: 0.849
# [9,  1200] loss: 0.873
# [9,  1400] loss: 0.873
# Accuracy of the network on the test images: 0.674
# [10,   200] loss: 0.779
# [10,   400] loss: 0.779
# [10,   600] loss: 0.795
# [10,   800] loss: 0.808
# [10,  1000] loss: 0.815
# [10,  1200] loss: 0.809
# [10,  1400] loss: 0.776
# Accuracy of the network on the test images: 0.670
# [11,   200] loss: 0.731
# [11,   400] loss: 0.753
# [11,   600] loss: 0.755
# [11,   800] loss: 0.759
# [11,  1000] loss: 0.765
# [11,  1200] loss: 0.733
# [11,  1400] loss: 0.764
# Accuracy of the network on the test images: 0.688
# [12,   200] loss: 0.672
# [12,   400] loss: 0.700
# [12,   600] loss: 0.699
# [12,   800] loss: 0.705
# [12,  1000] loss: 0.737
# [12,  1200] loss: 0.734
# [12,  1400] loss: 0.736
# Accuracy of the network on the test images: 0.684
# [13,   200] loss: 0.640
# [13,   400] loss: 0.678
# [13,   600] loss: 0.668
# [13,   800] loss: 0.673
# [13,  1000] loss: 0.648
# [13,  1200] loss: 0.703
# [13,  1400] loss: 0.685
# Accuracy of the network on the test images: 0.679
# [14,   200] loss: 0.635
# [14,   400] loss: 0.617
# [14,   600] loss: 0.616
# [14,   800] loss: 0.624
# [14,  1000] loss: 0.635
# [14,  1200] loss: 0.624
# [14,  1400] loss: 0.660
# Accuracy of the network on the test images: 0.692
# [15,   200] loss: 0.535
# [15,   400] loss: 0.584
# [15,   600] loss: 0.609
# [15,   800] loss: 0.611
# [15,  1000] loss: 0.598
# [15,  1200] loss: 0.604
# [15,  1400] loss: 0.641
# Accuracy of the network on the test images: 0.682
# [16,   200] loss: 0.513
# [16,   400] loss: 0.536
# [16,   600] loss: 0.554
# [16,   800] loss: 0.575
# [16,  1000] loss: 0.578
# [16,  1200] loss: 0.587
# [16,  1400] loss: 0.578
# Accuracy of the network on the test images: 0.696
# [17,   200] loss: 0.498
# [17,   400] loss: 0.512
# [17,   600] loss: 0.535
# [17,   800] loss: 0.555
# [17,  1000] loss: 0.524
# [17,  1200] loss: 0.551
# [17,  1400] loss: 0.557
# Accuracy of the network on the test images: 0.686
# [18,   200] loss: 0.469
# [18,   400] loss: 0.490
# [18,   600] loss: 0.498
# [18,   800] loss: 0.503
# [18,  1000] loss: 0.498
# [18,  1200] loss: 0.502
# [18,  1400] loss: 0.533
# Accuracy of the network on the test images: 0.677
# [19,   200] loss: 0.423
# [19,   400] loss: 0.447
# [19,   600] loss: 0.463
# [19,   800] loss: 0.475
# [19,  1000] loss: 0.485
# [19,  1200] loss: 0.504
# [19,  1400] loss: 0.509
# Accuracy of the network on the test images: 0.696
# [20,   200] loss: 0.389
# [20,   400] loss: 0.423
# [20,   600] loss: 0.423
# [20,   800] loss: 0.455
# [20,  1000] loss: 0.451
# [20,  1200] loss: 0.458
# [20,  1400] loss: 0.482
# Accuracy of the network on the test images: 0.685
# Finished Training
# Model saved to lenet-5_avg_pool.pth
# Accuracy of the network on the test images: 0.685

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(FiftyFiftyMaxAvgPool2d(2, 2), FiftyFiftyMaxAvgPool2d(2, 2))
net.to(device)
check_shapes(net, trainloader)
print(net.net2d[3].alpha)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.
# tensor([0.5000])

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_5050_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.289
# [1,   400] loss: 2.194
# [1,   600] loss: 1.992
# [1,   800] loss: 1.830
# [1,  1000] loss: 1.709
# [1,  1200] loss: 1.644
# [1,  1400] loss: 1.596
# Accuracy of the network on the test images: 0.430
# [2,   200] loss: 1.504
# [2,   400] loss: 1.447
# [2,   600] loss: 1.395
# [2,   800] loss: 1.355
# [2,  1000] loss: 1.330
# [2,  1200] loss: 1.312
# [2,  1400] loss: 1.272
# Accuracy of the network on the test images: 0.555
# [3,   200] loss: 1.257
# [3,   400] loss: 1.230
# [3,   600] loss: 1.216
# [3,   800] loss: 1.188
# [3,  1000] loss: 1.184
# [3,  1200] loss: 1.160
# [3,  1400] loss: 1.153
# Accuracy of the network on the test images: 0.588
# [4,   200] loss: 1.099
# [4,   400] loss: 1.118
# [4,   600] loss: 1.100
# [4,   800] loss: 1.112
# [4,  1000] loss: 1.099
# [4,  1200] loss: 1.087
# [4,  1400] loss: 1.089
# Accuracy of the network on the test images: 0.614
# [5,   200] loss: 1.021
# [5,   400] loss: 1.011
# [5,   600] loss: 1.033
# [5,   800] loss: 1.030
# [5,  1000] loss: 1.024
# [5,  1200] loss: 1.005
# [5,  1400] loss: 1.006
# Accuracy of the network on the test images: 0.620
# [6,   200] loss: 0.971
# [6,   400] loss: 0.954
# [6,   600] loss: 0.950
# [6,   800] loss: 0.945
# [6,  1000] loss: 0.957
# [6,  1200] loss: 0.956
# [6,  1400] loss: 0.935
# Accuracy of the network on the test images: 0.653
# [7,   200] loss: 0.909
# [7,   400] loss: 0.897
# [7,   600] loss: 0.913
# [7,   800] loss: 0.905
# [7,  1000] loss: 0.896
# [7,  1200] loss: 0.875
# [7,  1400] loss: 0.892
# Accuracy of the network on the test images: 0.666
# [8,   200] loss: 0.821
# [8,   400] loss: 0.862
# [8,   600] loss: 0.854
# [8,   800] loss: 0.836
# [8,  1000] loss: 0.848
# [8,  1200] loss: 0.843
# [8,  1400] loss: 0.821
# Accuracy of the network on the test images: 0.676
# [9,   200] loss: 0.799
# [9,   400] loss: 0.771
# [9,   600] loss: 0.758
# [9,   800] loss: 0.813
# [9,  1000] loss: 0.805
# [9,  1200] loss: 0.813
# [9,  1400] loss: 0.784
# Accuracy of the network on the test images: 0.673
# [10,   200] loss: 0.730
# [10,   400] loss: 0.739
# [10,   600] loss: 0.730
# [10,   800] loss: 0.752
# [10,  1000] loss: 0.751
# [10,  1200] loss: 0.778
# [10,  1400] loss: 0.750
# Accuracy of the network on the test images: 0.685
# [11,   200] loss: 0.667
# [11,   400] loss: 0.696
# [11,   600] loss: 0.722
# [11,   800] loss: 0.700
# [11,  1000] loss: 0.692
# [11,  1200] loss: 0.735
# [11,  1400] loss: 0.724
# Accuracy of the network on the test images: 0.697
# [12,   200] loss: 0.661
# [12,   400] loss: 0.652
# [12,   600] loss: 0.651
# [12,   800] loss: 0.680
# [12,  1000] loss: 0.670
# [12,  1200] loss: 0.662
# [12,  1400] loss: 0.669
# Accuracy of the network on the test images: 0.703
# [13,   200] loss: 0.608
# [13,   400] loss: 0.607
# [13,   600] loss: 0.616
# [13,   800] loss: 0.647
# [13,  1000] loss: 0.645
# [13,  1200] loss: 0.635
# [13,  1400] loss: 0.662
# Accuracy of the network on the test images: 0.698
# [14,   200] loss: 0.565
# [14,   400] loss: 0.577
# [14,   600] loss: 0.581
# [14,   800] loss: 0.574
# [14,  1000] loss: 0.639
# [14,  1200] loss: 0.591
# [14,  1400] loss: 0.609
# Accuracy of the network on the test images: 0.701
# [15,   200] loss: 0.522
# [15,   400] loss: 0.525
# [15,   600] loss: 0.552
# [15,   800] loss: 0.561
# [15,  1000] loss: 0.580
# [15,  1200] loss: 0.563
# [15,  1400] loss: 0.568
# Accuracy of the network on the test images: 0.691
# [16,   200] loss: 0.503
# [16,   400] loss: 0.507
# [16,   600] loss: 0.528
# [16,   800] loss: 0.542
# [16,  1000] loss: 0.530
# [16,  1200] loss: 0.511
# [16,  1400] loss: 0.536
# Accuracy of the network on the test images: 0.707
# [17,   200] loss: 0.466
# [17,   400] loss: 0.471
# [17,   600] loss: 0.479
# [17,   800] loss: 0.523
# [17,  1000] loss: 0.498
# [17,  1200] loss: 0.503
# [17,  1400] loss: 0.516
# Accuracy of the network on the test images: 0.705
# [18,   200] loss: 0.424
# [18,   400] loss: 0.443
# [18,   600] loss: 0.453
# [18,   800] loss: 0.492
# [18,  1000] loss: 0.457
# [18,  1200] loss: 0.483
# [18,  1400] loss: 0.499
# Accuracy of the network on the test images: 0.703
# [19,   200] loss: 0.395
# [19,   400] loss: 0.409
# [19,   600] loss: 0.414
# [19,   800] loss: 0.432
# [19,  1000] loss: 0.446
# [19,  1200] loss: 0.469
# [19,  1400] loss: 0.457
# Accuracy of the network on the test images: 0.702
# [20,   200] loss: 0.357
# [20,   400] loss: 0.373
# [20,   600] loss: 0.407
# [20,   800] loss: 0.413
# [20,  1000] loss: 0.417
# [20,  1200] loss: 0.422
# [20,  1400] loss: 0.439
# Accuracy of the network on the test images: 0.708
# Finished Training
# Model saved to lenet-5_5050_pool.pth
# Accuracy of the network on the test images: 0.708

# %%
print(net.net2d[3].alpha)
# Out:
# tensor([0.5000])

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(nn.MaxPool2d(2, 2), nn.AvgPool2d(2, 2))
net.to(device)
check_shapes(net, trainloader)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_max+avg_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.296
# [1,   400] loss: 2.253
# [1,   600] loss: 2.119
# [1,   800] loss: 1.952
# [1,  1000] loss: 1.841
# [1,  1200] loss: 1.770
# [1,  1400] loss: 1.706
# Accuracy of the network on the test images: 0.397
# [2,   200] loss: 1.578
# [2,   400] loss: 1.524
# [2,   600] loss: 1.475
# [2,   800] loss: 1.427
# [2,  1000] loss: 1.432
# [2,  1200] loss: 1.367
# [2,  1400] loss: 1.334
# Accuracy of the network on the test images: 0.537
# [3,   200] loss: 1.310
# [3,   400] loss: 1.254
# [3,   600] loss: 1.263
# [3,   800] loss: 1.237
# [3,  1000] loss: 1.243
# [3,  1200] loss: 1.244
# [3,  1400] loss: 1.202
# Accuracy of the network on the test images: 0.588
# [4,   200] loss: 1.159
# [4,   400] loss: 1.122
# [4,   600] loss: 1.141
# [4,   800] loss: 1.114
# [4,  1000] loss: 1.113
# [4,  1200] loss: 1.109
# [4,  1400] loss: 1.121
# Accuracy of the network on the test images: 0.616
# [5,   200] loss: 1.063
# [5,   400] loss: 1.025
# [5,   600] loss: 1.057
# [5,   800] loss: 1.038
# [5,  1000] loss: 1.036
# [5,  1200] loss: 1.003
# [5,  1400] loss: 1.035
# Accuracy of the network on the test images: 0.638
# [6,   200] loss: 0.982
# [6,   400] loss: 0.965
# [6,   600] loss: 0.995
# [6,   800] loss: 0.962
# [6,  1000] loss: 0.973
# [6,  1200] loss: 0.965
# [6,  1400] loss: 0.943
# Accuracy of the network on the test images: 0.655
# [7,   200] loss: 0.908
# [7,   400] loss: 0.929
# [7,   600] loss: 0.910
# [7,   800] loss: 0.898
# [7,  1000] loss: 0.913
# [7,  1200] loss: 0.914
# [7,  1400] loss: 0.905
# Accuracy of the network on the test images: 0.673
# [8,   200] loss: 0.845
# [8,   400] loss: 0.897
# [8,   600] loss: 0.867
# [8,   800] loss: 0.875
# [8,  1000] loss: 0.867
# [8,  1200] loss: 0.850
# [8,  1400] loss: 0.848
# Accuracy of the network on the test images: 0.667
# [9,   200] loss: 0.823
# [9,   400] loss: 0.803
# [9,   600] loss: 0.791
# [9,   800] loss: 0.828
# [9,  1000] loss: 0.821
# [9,  1200] loss: 0.816
# [9,  1400] loss: 0.829
# Accuracy of the network on the test images: 0.690
# [10,   200] loss: 0.756
# [10,   400] loss: 0.770
# [10,   600] loss: 0.777
# [10,   800] loss: 0.788
# [10,  1000] loss: 0.758
# [10,  1200] loss: 0.782
# [10,  1400] loss: 0.781
# Accuracy of the network on the test images: 0.692
# [11,   200] loss: 0.704
# [11,   400] loss: 0.720
# [11,   600] loss: 0.747
# [11,   800] loss: 0.748
# [11,  1000] loss: 0.750
# [11,  1200] loss: 0.719
# [11,  1400] loss: 0.723
# Accuracy of the network on the test images: 0.700
# [12,   200] loss: 0.658
# [12,   400] loss: 0.698
# [12,   600] loss: 0.686
# [12,   800] loss: 0.703
# [12,  1000] loss: 0.694
# [12,  1200] loss: 0.698
# [12,  1400] loss: 0.680
# Accuracy of the network on the test images: 0.689
# [13,   200] loss: 0.634
# [13,   400] loss: 0.655
# [13,   600] loss: 0.662
# [13,   800] loss: 0.656
# [13,  1000] loss: 0.662
# [13,  1200] loss: 0.664
# [13,  1400] loss: 0.645
# Accuracy of the network on the test images: 0.706
# [14,   200] loss: 0.610
# [14,   400] loss: 0.621
# [14,   600] loss: 0.620
# [14,   800] loss: 0.630
# [14,  1000] loss: 0.625
# [14,  1200] loss: 0.614
# [14,  1400] loss: 0.638
# Accuracy of the network on the test images: 0.708
# [15,   200] loss: 0.583
# [15,   400] loss: 0.550
# [15,   600] loss: 0.571
# [15,   800] loss: 0.601
# [15,  1000] loss: 0.591
# [15,  1200] loss: 0.591
# [15,  1400] loss: 0.586
# Accuracy of the network on the test images: 0.699
# [16,   200] loss: 0.527
# [16,   400] loss: 0.547
# [16,   600] loss: 0.547
# [16,   800] loss: 0.553
# [16,  1000] loss: 0.553
# [16,  1200] loss: 0.566
# [16,  1400] loss: 0.566
# Accuracy of the network on the test images: 0.704
# [17,   200] loss: 0.471
# [17,   400] loss: 0.510
# [17,   600] loss: 0.527
# [17,   800] loss: 0.531
# [17,  1000] loss: 0.546
# [17,  1200] loss: 0.508
# [17,  1400] loss: 0.550
# Accuracy of the network on the test images: 0.710
# [18,   200] loss: 0.445
# [18,   400] loss: 0.470
# [18,   600] loss: 0.479
# [18,   800] loss: 0.491
# [18,  1000] loss: 0.507
# [18,  1200] loss: 0.514
# [18,  1400] loss: 0.502
# Accuracy of the network on the test images: 0.707
# [19,   200] loss: 0.404
# [19,   400] loss: 0.451
# [19,   600] loss: 0.453
# [19,   800] loss: 0.466
# [19,  1000] loss: 0.490
# [19,  1200] loss: 0.492
# [19,  1400] loss: 0.478
# Accuracy of the network on the test images: 0.715
# [20,   200] loss: 0.399
# [20,   400] loss: 0.411
# [20,   600] loss: 0.437
# [20,   800] loss: 0.447
# [20,  1000] loss: 0.439
# [20,  1200] loss: 0.464
# [20,  1400] loss: 0.472
# Accuracy of the network on the test images: 0.703
# Finished Training
# Model saved to lenet-5_max+avg_pool.pth
# Accuracy of the network on the test images: 0.703

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(MixedMaxAvgPool2d(2, 2), MixedMaxAvgPool2d(2, 2))
net.to(device)
check_shapes(net, trainloader)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_mixed-max-avg_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.291
# [1,   400] loss: 2.239
# [1,   600] loss: 2.100
# [1,   800] loss: 1.946
# [1,  1000] loss: 1.825
# [1,  1200] loss: 1.747
# [1,  1400] loss: 1.666
# Accuracy of the network on the test images: 0.418
# [2,   200] loss: 1.545
# [2,   400] loss: 1.518
# [2,   600] loss: 1.455
# [2,   800] loss: 1.420
# [2,  1000] loss: 1.387
# [2,  1200] loss: 1.368
# [2,  1400] loss: 1.342
# Accuracy of the network on the test images: 0.534
# [3,   200] loss: 1.250
# [3,   400] loss: 1.266
# [3,   600] loss: 1.215
# [3,   800] loss: 1.221
# [3,  1000] loss: 1.213
# [3,  1200] loss: 1.189
# [3,  1400] loss: 1.157
# Accuracy of the network on the test images: 0.587
# [4,   200] loss: 1.095
# [4,   400] loss: 1.088
# [4,   600] loss: 1.109
# [4,   800] loss: 1.058
# [4,  1000] loss: 1.090
# [4,  1200] loss: 1.070
# [4,  1400] loss: 1.088
# Accuracy of the network on the test images: 0.607
# [5,   200] loss: 1.013
# [5,   400] loss: 1.004
# [5,   600] loss: 0.997
# [5,   800] loss: 1.017
# [5,  1000] loss: 0.984
# [5,  1200] loss: 0.993
# [5,  1400] loss: 0.971
# Accuracy of the network on the test images: 0.655
# [6,   200] loss: 0.910
# [6,   400] loss: 0.939
# [6,   600] loss: 0.927
# [6,   800] loss: 0.941
# [6,  1000] loss: 0.949
# [6,  1200] loss: 0.915
# [6,  1400] loss: 0.915
# Accuracy of the network on the test images: 0.656
# [7,   200] loss: 0.853
# [7,   400] loss: 0.872
# [7,   600] loss: 0.873
# [7,   800] loss: 0.876
# [7,  1000] loss: 0.852
# [7,  1200] loss: 0.861
# [7,  1400] loss: 0.840
# Accuracy of the network on the test images: 0.658
# [8,   200] loss: 0.817
# [8,   400] loss: 0.791
# [8,   600] loss: 0.798
# [8,   800] loss: 0.809
# [8,  1000] loss: 0.781
# [8,  1200] loss: 0.827
# [8,  1400] loss: 0.812
# Accuracy of the network on the test images: 0.665
# [9,   200] loss: 0.751
# [9,   400] loss: 0.769
# [9,   600] loss: 0.760
# [9,   800] loss: 0.736
# [9,  1000] loss: 0.748
# [9,  1200] loss: 0.753
# [9,  1400] loss: 0.755
# Accuracy of the network on the test images: 0.699
# [10,   200] loss: 0.686
# [10,   400] loss: 0.690
# [10,   600] loss: 0.708
# [10,   800] loss: 0.721
# [10,  1000] loss: 0.685
# [10,  1200] loss: 0.747
# [10,  1400] loss: 0.712
# Accuracy of the network on the test images: 0.694
# [11,   200] loss: 0.636
# [11,   400] loss: 0.645
# [11,   600] loss: 0.659
# [11,   800] loss: 0.672
# [11,  1000] loss: 0.675
# [11,  1200] loss: 0.658
# [11,  1400] loss: 0.675
# Accuracy of the network on the test images: 0.695
# [12,   200] loss: 0.612
# [12,   400] loss: 0.620
# [12,   600] loss: 0.611
# [12,   800] loss: 0.601
# [12,  1000] loss: 0.635
# [12,  1200] loss: 0.636
# [12,  1400] loss: 0.636
# Accuracy of the network on the test images: 0.705
# [13,   200] loss: 0.539
# [13,   400] loss: 0.586
# [13,   600] loss: 0.573
# [13,   800] loss: 0.599
# [13,  1000] loss: 0.591
# [13,  1200] loss: 0.633
# [13,  1400] loss: 0.632
# Accuracy of the network on the test images: 0.698
# [14,   200] loss: 0.522
# [14,   400] loss: 0.506
# [14,   600] loss: 0.553
# [14,   800] loss: 0.552
# [14,  1000] loss: 0.540
# [14,  1200] loss: 0.557
# [14,  1400] loss: 0.568
# Accuracy of the network on the test images: 0.705
# [15,   200] loss: 0.474
# [15,   400] loss: 0.493
# [15,   600] loss: 0.493
# [15,   800] loss: 0.504
# [15,  1000] loss: 0.544
# [15,  1200] loss: 0.497
# [15,  1400] loss: 0.545
# Accuracy of the network on the test images: 0.700
# [16,   200] loss: 0.450
# [16,   400] loss: 0.435
# [16,   600] loss: 0.453
# [16,   800] loss: 0.487
# [16,  1000] loss: 0.474
# [16,  1200] loss: 0.499
# [16,  1400] loss: 0.528
# Accuracy of the network on the test images: 0.700
# [17,   200] loss: 0.416
# [17,   400] loss: 0.432
# [17,   600] loss: 0.434
# [17,   800] loss: 0.440
# [17,  1000] loss: 0.442
# [17,  1200] loss: 0.491
# [17,  1400] loss: 0.494
# Accuracy of the network on the test images: 0.699
# [18,   200] loss: 0.365
# [18,   400] loss: 0.380
# [18,   600] loss: 0.405
# [18,   800] loss: 0.417
# [18,  1000] loss: 0.423
# [18,  1200] loss: 0.434
# [18,  1400] loss: 0.449
# Accuracy of the network on the test images: 0.697
# [19,   200] loss: 0.353
# [19,   400] loss: 0.349
# [19,   600] loss: 0.375
# [19,   800] loss: 0.388
# [19,  1000] loss: 0.398
# [19,  1200] loss: 0.400
# [19,  1400] loss: 0.430
# Accuracy of the network on the test images: 0.685
# [20,   200] loss: 0.326
# [20,   400] loss: 0.338
# [20,   600] loss: 0.349
# [20,   800] loss: 0.348
# [20,  1000] loss: 0.366
# [20,  1200] loss: 0.379
# [20,  1400] loss: 0.392
# Accuracy of the network on the test images: 0.701
# Finished Training
# Model saved to lenet-5_mixed-max-avg_pool.pth
# Accuracy of the network on the test images: 0.701

# %%
# Let's test the shapes of the tensors
# Create a network
net = Net(MinPool2d(2, 2), MinPool2d(2, 2))
net.to(device)
check_shapes(net, trainloader)
# Out:
# Shape of the input tensor: torch.Size([32, 3, 32, 32])
# The shapes seem to be ok.

# %%
train_model(net, n_epochs)
save_model(net, 'lenet-5_min_pool.pth')
# Let us compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
# Out:
# [1,   200] loss: 2.302
# [1,   400] loss: 2.274
# [1,   600] loss: 2.202
# [1,   800] loss: 2.175
# [1,  1000] loss: 2.123
# [1,  1200] loss: 2.064
# [1,  1400] loss: 1.987
# Accuracy of the network on the test images: 0.315
# [2,   200] loss: 1.851
# [2,   400] loss: 1.743
# [2,   600] loss: 1.711
# [2,   800] loss: 1.655
# [2,  1000] loss: 1.621
# [2,  1200] loss: 1.594
# [2,  1400] loss: 1.574
# Accuracy of the network on the test images: 0.443
# [3,   200] loss: 1.513
# [3,   400] loss: 1.485
# [3,   600] loss: 1.464
# [3,   800] loss: 1.455
# [3,  1000] loss: 1.431
# [3,  1200] loss: 1.421
# [3,  1400] loss: 1.405
# Accuracy of the network on the test images: 0.501
# [4,   200] loss: 1.377
# [4,   400] loss: 1.349
# [4,   600] loss: 1.325
# [4,   800] loss: 1.345
# [4,  1000] loss: 1.345
# [4,  1200] loss: 1.316
# [4,  1400] loss: 1.331
# Accuracy of the network on the test images: 0.529
# [5,   200] loss: 1.276
# [5,   400] loss: 1.283
# [5,   600] loss: 1.272
# [5,   800] loss: 1.277
# [5,  1000] loss: 1.250
# [5,  1200] loss: 1.245
# [5,  1400] loss: 1.233
# Accuracy of the network on the test images: 0.530
# [6,   200] loss: 1.214
# [6,   400] loss: 1.190
# [6,   600] loss: 1.183
# [6,   800] loss: 1.202
# [6,  1000] loss: 1.155
# [6,  1200] loss: 1.206
# [6,  1400] loss: 1.184
# Accuracy of the network on the test images: 0.573
# [7,   200] loss: 1.156
# [7,   400] loss: 1.115
# [7,   600] loss: 1.141
# [7,   800] loss: 1.117
# [7,  1000] loss: 1.145
# [7,  1200] loss: 1.149
# [7,  1400] loss: 1.107
# Accuracy of the network on the test images: 0.564
# [8,   200] loss: 1.074
# [8,   400] loss: 1.070
# [8,   600] loss: 1.096
# [8,   800] loss: 1.071
# [8,  1000] loss: 1.086
# [8,  1200] loss: 1.069
# [8,  1400] loss: 1.071
# Accuracy of the network on the test images: 0.586
# [9,   200] loss: 1.012
# [9,   400] loss: 1.060
# [9,   600] loss: 1.017
# [9,   800] loss: 1.021
# [9,  1000] loss: 1.025
# [9,  1200] loss: 1.027
# [9,  1400] loss: 1.006
# Accuracy of the network on the test images: 0.589
# [10,   200] loss: 0.984
# [10,   400] loss: 0.956
# [10,   600] loss: 1.003
# [10,   800] loss: 0.978
# [10,  1000] loss: 0.996
# [10,  1200] loss: 1.006
# [10,  1400] loss: 0.978
# Accuracy of the network on the test images: 0.610
# [11,   200] loss: 0.940
# [11,   400] loss: 0.954
# [11,   600] loss: 0.945
# [11,   800] loss: 0.936
# [11,  1000] loss: 0.926
# [11,  1200] loss: 0.941
# [11,  1400] loss: 0.941
# Accuracy of the network on the test images: 0.624
# [12,   200] loss: 0.868
# [12,   400] loss: 0.898
# [12,   600] loss: 0.925
# [12,   800] loss: 0.900
# [12,  1000] loss: 0.896
# [12,  1200] loss: 0.925
# [12,  1400] loss: 0.903
# Accuracy of the network on the test images: 0.625
# [13,   200] loss: 0.873
# [13,   400] loss: 0.864
# [13,   600] loss: 0.877
# [13,   800] loss: 0.860
# [13,  1000] loss: 0.849
# [13,  1200] loss: 0.867
# [13,  1400] loss: 0.884
# Accuracy of the network on the test images: 0.620
# [14,   200] loss: 0.827
# [14,   400] loss: 0.802
# [14,   600] loss: 0.833
# [14,   800] loss: 0.851
# [14,  1000] loss: 0.816
# [14,  1200] loss: 0.808
# [14,  1400] loss: 0.856
# Accuracy of the network on the test images: 0.632
# [15,   200] loss: 0.783
# [15,   400] loss: 0.789
# [15,   600] loss: 0.792
# [15,   800] loss: 0.783
# [15,  1000] loss: 0.831
# [15,  1200] loss: 0.793
# [15,  1400] loss: 0.810
# Accuracy of the network on the test images: 0.629
# [16,   200] loss: 0.729
# [16,   400] loss: 0.767
# [16,   600] loss: 0.759
# [16,   800] loss: 0.766
# [16,  1000] loss: 0.761
# [16,  1200] loss: 0.771
# [16,  1400] loss: 0.804
# Accuracy of the network on the test images: 0.631
# [17,   200] loss: 0.702
# [17,   400] loss: 0.737
# [17,   600] loss: 0.742
# [17,   800] loss: 0.747
# [17,  1000] loss: 0.722
# [17,  1200] loss: 0.752
# [17,  1400] loss: 0.738
# Accuracy of the network on the test images: 0.635
# [18,   200] loss: 0.667
# [18,   400] loss: 0.699
# [18,   600] loss: 0.665
# [18,   800] loss: 0.703
# [18,  1000] loss: 0.713
# [18,  1200] loss: 0.695
# [18,  1400] loss: 0.733
# Accuracy of the network on the test images: 0.629
# [19,   200] loss: 0.611
# [19,   400] loss: 0.664
# [19,   600] loss: 0.665
# [19,   800] loss: 0.670
# [19,  1000] loss: 0.684
# [19,  1200] loss: 0.694
# [19,  1400] loss: 0.697
# Accuracy of the network on the test images: 0.630
# [20,   200] loss: 0.597
# [20,   400] loss: 0.619
# [20,   600] loss: 0.626
# [20,   800] loss: 0.655
# [20,  1000] loss: 0.649
# [20,  1200] loss: 0.666
# [20,  1400] loss: 0.669
# Accuracy of the network on the test images: 0.633
# Finished Training
# Model saved to lenet-5_min_pool.pth
# Accuracy of the network on the test images: 0.633

# %% [markdown]
# epochs: 10
#
# LP: 0.695, 0.696, 0.700
#
# Max: 0.695, 0.694, 0.685
#
# Avg: 0.657, 0.678, 0.670
#
# 5050: 0.689, 0.698, 0.685
#
# max->avg: 0.689, 0.698, 0.692
#
# mixed: 0.679, 0.683, 0.694
#
# min: 0.610, 0.618, 0.610

# %% [markdown]
# epochs: 20
#
# LP: 0.686
#
# max: 0.674
#
# avg: 0.685
#
# 5050: 0.708
#
# max->avg: 0.703
#
# mixed: 0.701
#
# min: 0.633
